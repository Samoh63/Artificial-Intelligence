# %% [markdown]
# # N Queen Problem
# ### The N Queen is the problem of placing N chess queens on an N×N chessboard so that no two queens attack each other
# <center><img src="./Images/8queen.png" class="bg-primary mb-3"></center><br>

# %%
import random
from IPython.display import Image

# %% [markdown]
# ### 1) Generate initial population (n random chromosome)
# Suppose that each queen is located in each column of chess board. Thus, every digit in a chromosome shows the location of queen in a column. For example, [2,3,6,8,5,4,2,7] shows a 8*8 chess board that queen in column 3 is located n row 6.  **Size** in this function shows the number of chromosomes produced in this step.
# <center><img src="./Images/chromosome.png" class="bg-primary mb-3"></center><br>

# %%
def random_chromosome(size):  # making random chromosomes
    return [random.randint(1, size) for _ in range(size)]

# %% [markdown]
# ### 2) Find the value of fitness function for each chromosome
# **Fitness function**: the number of nonattacking pairs of queens
#
# Since that we supposed that each queen i located in each column, there is no possibility to see attcking queen in a column. Hence, we must check whether a quuen aatcks any piece in the same row or diagonal.
#
# 1) &emsp;To compute collision in a row,the only thing we have to do is to look for the same number in the chromosomes.
# 2) &emsp;To compute collision in diagonals, there are twoo methods:<br>
# &emsp;&emsp;(a)&emsp;For a simple method of finding conflicts [4], consider an ntuple: $(q_{1},..., q_{i},..., q_{j}, ..., q_{n})$. i-th and j-th queen share a
# diagonal if:<br>
# $$ i - q_{i} = j - q_{j}$$
# $$or$$
# $$i + q_{i} = j + q_{j}$$
# &emsp;&emsp;&emsp;which reduces to:
# $$ |q_{i} - q_{j}| = |i - j|$$
# &emsp;&emsp;&emsp;This simple approach results in fitness function with complexity of $O(n^{2})$. It is possible to reduce complexity to $O(n)$ by observing diagonals on the board as the following.
# &emsp;&emsp;(b)&emsp; Left and right are defined in this method, Fig. 1. There are $2n-1$ "left" (left to right) and $2n-1$ "right" (right to left) diagonals.<br>
# &emsp;&emsp; In this situation, there is no need to compute nested loop and just need to compute the number of queens in each diagonal. Thus, fitness function is of order $ O(n^{2})$.
# <center><img src="./Images/Left.png" class="bg-primary mb-3"><img src="./Images/Right.png" class="bg-primary mb-3" ></center><br>

# %%
#  Method (b)
def fitness(chromosome):
    horizontal_collisions = sum(
        [chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = [0] * 2*n
    right_diagonal = [0] * 2*n
    for i in range(n):
        left_diagonal[i + chromosome[i] - 1] += 1
        right_diagonal[len(chromosome) - i + chromosome[i] - 2] += 1

    diagonal_collisions = 0
    for i in range(2*n-1):
        counter = 0
        if left_diagonal[i] > 1:
            counter += left_diagonal[i]*(left_diagonal[i]-1)/2
        if right_diagonal[i] > 1:
            counter += right_diagonal[i]*(right_diagonal[i]-1)/2
        diagonal_collisions += counter  # / (n-abs(i-n+1))
    # 28-(2+3)=23
    return int(maxFitness - (horizontal_collisions + diagonal_collisions))


# Method (a)
def fitness1(chromosome):
    horizontal_collisions = sum(
    [chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    for i in range(n):

        for j in range(i + 1, n):
            if (abs(i - j) == abs(chromosome[i] - chromosome[j])) and (chromosome[i] != chromosome[j]):
                diagonal_collisions += 1
    return int(maxFitness-(horizontal_collisions + diagonal_collisions))

# %% [markdown]
# ### 3) Sorting chromosome based on **Fitness function**
# &emsp; Sorting population and eliminate the weak chromosomes

# %%
def survival(population, fitness):
    fitnessPopulation = [fitness(n) for n in population]
    populationWithHighFitness = zip(population, fitnessPopulation)
    populationWithHighFitness = list(populationWithHighFitness)

    sortedPopulation = sorted(
        populationWithHighFitness, key=lambda x: x[1], reverse=True)
    
    survivalPopolation = []
    for i in range(int(len(sortedPopulation)/2)):
        
        survivalPopolation.append(sortedPopulation[i][0])
        # print(sortedPopulation)
    return survivalPopolation

# %% [markdown]
# ### 4) Select mates based on  **Roulette Wheel weighting**
# &emsp; a) The probability of selection is calculated from the fitness function of the chromosome rather.

# %%
def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

# %% [markdown]
# &emsp; b) Random function: A random number between zero and one is generated.

# %%
def random_pick(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(w for c, w in populationWithProbabilty)
    r = random.uniform(0, total)
    upto = 0
    for c, w in zip(population, probabilities):
        if upto + w >= r:
            return c
        upto += w
    assert False, "Shouldn't get here"

# %% [markdown]
# ### 5) Mating:
# Mating is the creation of one or more offspring from the parents selected in the pairing process

# %%
def mating(x, y):  # doing cross_over between two chromosomes
    n = len(x)
    c = random.randint(0, n - 1)
    return x[0:c] + y[c:n]

# %% [markdown]
# ### 6) Mutation:
# Random mutations alter a certain percentage of the bits in the list of chromosomes. In this problem

# %%
def mutate(x):  # randomly changing the value of a random index of a chromosome
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(1, n)
    x[c] = m
    return x

# %% [markdown]
# ## Genetic Algorithm

# %%
def genetic_algorithm(population, fitness):
    mutation_probability = 0.06
    best_population = survival(population, fitness)
    probabilities = [probability(n, fitness) for n in best_population]
    nn = len(best_population)
    for i in range(nn):
        x = random_pick(population, probabilities)  # best chromosome 1
        y = random_pick(population, probabilities)  # best chromosome 2
        # creating two new chromosomes from the best 2 chromosomes
        child = mating(x, y)
        if (random.random() < mutation_probability): 
            child = mutate(child)
            if i != 0 :   # Elitism
                best_population[i] = mutate(best_population[i])
            
        print_chromosome(child)
        best_population.append(child)
        # print(best_population)
        if fitness(child) == maxFitness:
            break
    return best_population

# %%
def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
          .format(str(chrom), fitness(chrom)))

# %%
if __name__ == "__main__":
    nq = int(input("Enter Number of Queens: "))  # say N = 8
    maxFitness = (nq*(nq-1))/2  # n (n - 1)/2 = 8 * 7 / 2 = 28
    population = [random_chromosome(nq) for _ in range(10)]
    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print("=== Generation {} ===".format(generation))
        population = genetic_algorithm(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(
            max([fitness(n) for n in population])))
        generation += 1
    chrom_out = []
    print("Solved in Generation {}!".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("")
            print("One of the solutions: ")
            chrom_out = chrom
            print_chromosome(chrom)

    board = []

    for x in range(nq):
        board.append(["x"] * nq)

    for i in range(nq):
        board[nq-chrom_out[i]][i] = "Q"

    def print_board(board):
        for row in board:
            print(" ".join(row))

    print()
    print_board(board)
# Out:
# === Generation 1 ===
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 5, 4, 3, 8, 2],  Fitness = 22
# Chromosome = [6, 1, 7, 2, 3, 5, 5, 8],  Fitness = 23
# Chromosome = [8, 3, 5, 6, 7, 4, 6, 8],  Fitness = 22
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
#
# Maximum Fitness = 23
# === Generation 2 ===
# Chromosome = [4, 5, 3, 2, 7, 3, 5, 8],  Fitness = 21
# Chromosome = [1, 1, 7, 5, 4, 3, 8, 2],  Fitness = 21
# Chromosome = [6, 5, 1, 8, 1, 5, 3, 2],  Fitness = 23
# Chromosome = [6, 3, 5, 6, 1, 5, 3, 2],  Fitness = 20
# Chromosome = [1, 6, 1, 8, 1, 5, 3, 2],  Fitness = 22
#
# Maximum Fitness = 23
# === Generation 3 ===
# Chromosome = [6, 1, 7, 2, 3, 4, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 5, 8],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 4, 8, 1],  Fitness = 23
# Chromosome = [1, 6, 8, 4, 2, 4, 5, 8],  Fitness = 21
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 4 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 3, 2],  Fitness = 21
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 8],  Fitness = 20
# Chromosome = [6, 6, 8, 4, 2, 4, 8, 1],  Fitness = 22
# Chromosome = [4, 5, 1, 8, 2, 4, 8, 1],  Fitness = 22
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
#
# Maximum Fitness = 25
# === Generation 5 ===
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [4, 5, 1, 8, 1, 4, 8, 1],  Fitness = 21
# Chromosome = [6, 1, 7, 2, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 3, 2],  Fitness = 21
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
#
# Maximum Fitness = 25
# === Generation 6 ===
# Chromosome = [1, 1, 7, 2, 3, 5, 5, 8],  Fitness = 21
# Chromosome = [4, 5, 1, 8, 1, 5, 5, 8],  Fitness = 20
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [4, 5, 1, 8, 1, 5, 3, 2],  Fitness = 23
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 2],  Fitness = 22
#
# Maximum Fitness = 25
# === Generation 7 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [4, 5, 8, 4, 2, 4, 8, 1],  Fitness = 22
# Chromosome = [1, 6, 7, 2, 3, 5, 5, 8],  Fitness = 21
# Chromosome = [6, 1, 8, 4, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
#
# Maximum Fitness = 25
# === Generation 8 ===
# Chromosome = [6, 1, 8, 4, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 2],  Fitness = 22
# Chromosome = [4, 5, 8, 4, 2, 4, 8, 1],  Fitness = 22
# Chromosome = [1, 6, 8, 4, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [1, 6, 2, 2, 3, 5, 8, 1],  Fitness = 23
#
# Maximum Fitness = 25
# === Generation 9 ===
# Chromosome = [4, 5, 1, 4, 2, 4, 8, 1],  Fitness = 21
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 2, 4, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [1, 6, 8, 4, 3, 5, 8, 1],  Fitness = 21
#
# Maximum Fitness = 25
# === Generation 10 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [1, 6, 7, 2, 3, 5, 8, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 1, 5, 3, 2],  Fitness = 20
#
# Maximum Fitness = 25
# === Generation 11 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 12 ===
# Chromosome = [6, 1, 7, 2, 3, 1, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 13 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 14 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 15 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 16 ===
# Chromosome = [6, 1, 7, 2, 3, 7, 8, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 17 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 18 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 8],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 19 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 5, 2, 3, 5, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 4, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 20 ===
# Chromosome = [6, 1, 7, 2, 3, 7, 8, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 7, 8, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 7, 8, 1],  Fitness = 24
#
# Maximum Fitness = 25
# === Generation 21 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 22 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 23 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 24 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 25 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 26 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 27 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 28 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 29 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 30 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 31 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 32 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 5, 3, 5, 8, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 7, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 33 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 7, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 34 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 35 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 36 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 37 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 38 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 6, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 39 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 8, 3, 5, 8, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 40 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 41 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 42 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 7],  Fitness = 22
# Chromosome = [6, 1, 7, 2, 4, 5, 8, 1],  Fitness = 23
#
# Maximum Fitness = 25
# === Generation 43 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 4, 1],  Fitness = 24
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 44 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 45 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 46 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 47 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 48 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 49 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 50 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 6, 1],  Fitness = 22
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 51 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 52 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 53 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 54 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 55 ===
# Chromosome = [6, 1, 7, 3, 3, 5, 8, 1],  Fitness = 22
# Chromosome = [6, 1, 7, 3, 3, 5, 8, 1],  Fitness = 22
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 56 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 57 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 58 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 25
# === Generation 59 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 60 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 26
# === Generation 61 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 4],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 62 ===
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 1, 7, 2, 3, 5, 2, 1],  Fitness = 23
# Chromosome = [6, 1, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 63 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 6, 7, 2, 3, 5, 8, 1],  Fitness = 24
#
# Maximum Fitness = 26
# === Generation 64 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 65 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 66 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 4, 5, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 67 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 8],  Fitness = 25
#
# Maximum Fitness = 26
# === Generation 68 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 69 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 70 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 71 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 7, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 72 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 73 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 74 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [1, 4, 7, 2, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 5, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 75 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 76 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 1, 8, 1],  Fitness = 24
#
# Maximum Fitness = 26
# === Generation 77 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 4, 3, 1, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 1, 8, 1],  Fitness = 24
#
# Maximum Fitness = 26
# === Generation 78 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 26
# === Generation 79 ===
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 4, 5, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 80 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 81 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 82 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 83 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 84 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 85 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 86 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 87 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 88 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 89 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 90 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 91 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 92 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 93 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 94 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 95 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 96 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 97 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 98 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 99 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 100 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 101 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 102 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 103 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 104 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 105 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 106 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 107 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 108 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 109 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 110 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 111 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 112 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 4, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 113 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 114 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 7, 7, 1, 3, 5, 8, 1],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 115 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 116 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [2, 2, 7, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [2, 4, 7, 1, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 117 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 118 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 119 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 120 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 121 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 122 ===
# Chromosome = [6, 8, 7, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 123 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 2, 1, 3, 5, 8, 8],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 124 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 4, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 125 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 126 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 127 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 128 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 129 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 7, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 7, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 130 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 3, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 131 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 132 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 133 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 5, 7, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 6, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 134 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 135 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 136 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 137 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 138 ===
# Chromosome = [7, 4, 7, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 139 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 140 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 141 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 142 ===
# Chromosome = [6, 4, 7, 1, 3, 3, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 143 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 144 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 2, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 145 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 146 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 147 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 8],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 148 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 4],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 149 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 2, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 150 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 4],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 151 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 4],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 152 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 7, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 3, 7, 1, 3, 5, 8, 1],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 153 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 7],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 4],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 4],  Fitness = 27
# Chromosome = [6, 6, 7, 1, 3, 5, 8, 4],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 7],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 154 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 155 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [5, 4, 7, 1, 3, 5, 8, 1],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 156 ===
# ...
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 186 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 187 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 188 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 189 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 190 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 3, 8, 1],  Fitness = 24
# Chromosome = [6, 2, 7, 1, 3, 7, 8, 1],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 191 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 7, 8, 1],  Fitness = 25
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 192 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 6, 1, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 193 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 194 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 195 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 196 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 197 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 198 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 199 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 2, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 200 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 2, 3, 5, 8, 1],  Fitness = 26
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 201 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 7],  Fitness = 25
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 202 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [5, 4, 7, 1, 3, 5, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 203 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 204 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 205 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 6, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 206 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [5, 2, 7, 1, 3, 5, 8, 1],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 207 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 208 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 209 ===
# Chromosome = [6, 4, 7, 1, 3, 3, 8, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 5, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 210 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 211 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 212 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 4, 1],  Fitness = 24
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 213 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 8, 8, 1],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 214 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 6, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 215 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 216 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 217 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 218 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 219 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 220 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 221 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 1, 1],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 222 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 223 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 224 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 8, 7, 1, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 225 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 3, 3, 5, 8, 1],  Fitness = 25
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 226 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 227 ===
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 228 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 229 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 230 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [1, 2, 7, 1, 3, 5, 8, 1],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 231 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 232 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 233 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 234 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
#
# Maximum Fitness = 27
# === Generation 235 ===
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 3],  Fitness = 26
# Chromosome = [6, 4, 7, 1, 3, 5, 8, 1],  Fitness = 27
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 4],  Fitness = 28
#
# Maximum Fitness = 28
# Solved in Generation 235!
#
# One of the solutions:
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 4],  Fitness = 28
#
# One of the solutions:
# Chromosome = [6, 2, 7, 1, 3, 5, 8, 4],  Fitness = 28
#
# x x x x x x Q x
# x x Q x x x x x
# Q x x x x x x x
# x x x x x Q x x
# x x x x x x x Q
# x x x x Q x x x
# x Q x x x x x x
# x x x Q x x x x

# %% [markdown]
# Ref: Solving n-Queen problem using global parallel genetic algorithm Extended Abstract
# Marko Božikovi, Marin Golub, Leo Budin
